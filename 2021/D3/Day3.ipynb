# %% [markdown]
# # Day 3: Binary Diagnostic

# %%
import numpy as np

# %% [markdown]
# ## Part 1

# %%
data = np.loadtxt('input.txt', dtype=str)

# %%
n = len(data)
bin_list_gamma = []
for i in range(len(data[0])):
    ones = 0
    for y in data:
#         print(y[i])
        ones += int(y[i])
    if ones > n/2:
        bin_list_gamma.append(1)
    else:
        bin_list_gamma.append(0)
print(bin_list)

gamma = 0
for b in bin_list_gamma:
    gamma = (2 * gamma) + b
print(gamma)
# Out:
# [0, 1, 1, 0, 0, 1, 0, 1, 0, 0, 0, 0]
# 1616

# %%
bin_list_epsilon = [1 if x < 1 else 0 for x in bin_list_gamma]
epsilon= 0
for b in bin_list_epsilon:
    epsilon = (2 * epsilon) + b
print(epsilon)
# Out:
# 2479

# %%
power = gamma * epsilon
print(power)
# Out:
# 4006064

# %% [markdown]
# ## Part 2

# %%
n = len(data)
bin_list_oxygen = []
for i in range(len(data[0])):
    ones = 0
    for y in data:
#         print(y[i])
        ones += int(y[i])
    if ones > n/2:
        bin_list_gamma.append(1)
        
    else:
        bin_list_gamma.append(0)
print(bin_list)
# Out:
# array(['110011101111', '011110010111', '101010111001', '110011100110',
#        '110010000101', '000111001111', '001111110011', '100000111010',
#        '101010000110', '001000100011', '110000000100', '000100110000',
#        '010010101110', '101110111101', '100000100111', '111011010111',
#        '001101010010', '010010001111', '010101100001', '111001101101',
#        '110110000011', '000110111111', '111111100010', '110010101011',
#        '010011100100', '110011010010', '100001111010', '000101000110',
#        '110001000111', '110110000001', '101011010110', '101001011010',
#        '100101000110', '101010110001', '111000110110', '111000001111',
#        '010111101111', '000001001011', '000001111101', '000111010101',
#        '110101111110', '110000100101', '011101110101', '011101000000',
#        '111011100101', '011100001101', '000010100001', '010010010100',
#        '001010100110', '001111110110', '111110101001', '000010101101',
# ...

# %%
np.where(data[:][1] == '1')
# Out:
# (array([], dtype=int64),)

# %%
data2 = data.copy()
m = len(data2[0])
n = len(data2)

for i in range(m):
    for y in data:
#         print(y)
        if y[i] == '1':
            print(np.argwhere(data2 == y))
            
# n = len(data2)
# print(n)
# print(m)
# Out:
# [[0]]
# [[2]]
# [[3]]
# [[4]]
# [[7]]
# [[8]]
# [[10]]
# [[13]]
# [[14]]
# [[15]]
# [[19]]
# [[20]]
# [[22]]
# [[23]]
# [[25]]
# [[26]]
# [[28]]
# [[29]]
# [[30]]
# [[31]]
# [[32]]
# [[33]]
# [[34]]
# [[35]]
# [[40]]
# [[41]]
# [[44]]
# [[50]]
# [[52]]
# [[55]]
# [[59]]
# [[61]]
# [[63]]
# [[64]]
# [[65]]
# [[66]]
# [[70]]
# [[72]]
# [[74]]
# [[77]]
# [[78]]
# [[80]]
# [[81]]
# [[85]]
# [[88]]
# [[92]]
# [[93]]
# [[96]]
# [[97]]
# [[99]]
# [[100]]
# [[101]]
# [[102]]
# [[103]]
# [[106]]
# [[111]]
# [[114]]
# [[116]]
# [[117]]
# [[118]]
# [[119]]
# [[120]]
# [[123]]
# [[124]]
# [[126]]
# [[129]]
# [[130]]
# [[135]]
# [[140]]
# [[143]]
# [[144]]
# [[146]]
# [[147]]
# [[149]]
# [[153]]
# [[154]]
# [[155]]
# [[157]]
# [[159]]
# [[163]]
# [[166]]
# [[168]]
# [[169]]
# [[171]]
# [[172]]
# [[173]]
# [[176]]
# [[182]]
# [[183]]
# [[184]]
# [[185]]
# [[187]]
# [[189]]
# [[191]]
# [[193]]
# [[197]]
# [[198]]
# [[203]]
# [[205]]
# [[206]]
# [[207]]
# [[208]]
# [[211]]
# [[213]]
# [[214]]
# ...
